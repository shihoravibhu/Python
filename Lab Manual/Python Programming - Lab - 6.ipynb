# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 6</b></center>
# <center><b><h4>Roll No. : 459</b></center>
# <center><b><h4>Name : Vibhu Shihora</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to find sum of all the elements in a List.

# %%
list = [1,3,5,7]

sum = 0

for i in list:
    sum += i

print("Sum : " , sum)
# Out:
# Sum :  16

# %% [markdown]
# ### 02) WAP to find largest element in a List.

# %%
list = [2,4,5]

# print(max(list))

# or

mx = list[0]
for i in list:
    if mx < i:
        mx = i

print(mx)
# Out:
# 5

# %% [markdown]
# ### 03) WAP to find the length of a List.

# %%
list = [1,3,5,6]

count = 0

for i in list:
    count+=1

print("Len : ",count)
# Out:
# Len :  4

# %% [markdown]
# ### 04) WAP to interchange first and last elements in a list.

# %%
list = [1,3,5,6]

temp = list[0]
list[0] = list[-1]
list[-1] = temp

print(list)
# Out:
# [6, 3, 5, 1]

# %% [markdown]
# ### 05) WAP to split the List into two parts and append the first part to the end.

# %%
list = [1,3,4,5,6]

p = int(input("Enter Position To Split : "))

left = list[:p+1]
right = list[p+1:]

list = right + left

print(list)
# Out:
# Enter Position To Split :  2
# [5, 6, 1, 3, 4]

# %% [markdown]
# ### 06) WAP to interchange the elements on two positions entered by a user.

# %%
list = [1,3,5,6]

p1 = int(input("Enter Position 1 : "))
p2 = int(input("Enter Position 2 : "))

temp = list[p1]
list[p1] = list[p2]
list[p2] = temp

print(list)
# Out:
# Enter Position 1 :  1
# Enter Position 2 :  3
# [1, 6, 5, 3]

# %% [markdown]
# ### 07) WAP to reverse the list entered by user.

# %%
n = int(input("Enter Length : "))

list = []

for i in range(n):     
    list.append(int(input(f"Enter {i+1} Element :")))

# list = list[::-1]

# or

list.reverse()

print(list)
# Out:
# Enter Length :  4
# Enter 1 Element : 2
# Enter 2 Element : 3
# Enter 3 Element : 5
# Enter 4 Element : 5
# [2, 3, 5, 5]

# %% [markdown]
# ### 08) WAP to print even numbers in a list.

# %%
list = [1,2,3,4]

for i in list:
    if(i % 2 == 0):
        print(i)
# Out:
# 2
# 4

# %% [markdown]
# ### 09) WAP to count unique items in a list.

# %%
list = [11,11,4,4,66]

unique = 0

for i in list:
    if(list.count(i) == 1):
        unique += 1

print(unique)
# Out:
# 1

# %% [markdown]
# ### 10) WAP to copy a list.

# %%
list = [1,2,3,4,5]

list2 = list.copy()

# or

# list2 = list  # Refrance Same  

print(list2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 11) WAP to print all odd numbers in a given range.

# %%
a = int(input("Enter a : "))
b = int(input("Enter b : "))

for i in range(a,b+1):
    if(i % 2 != 0):
        print(i)
# Out:
# Enter a :  5
# Enter b :  10
# 5
# 7
# 9

# %% [markdown]
# ### 12) WAP to count occurrences of an element in a list.

# %%
list = [11,2,2,3,4,5,55,6,11,11,55,11]

for i in set(list):        
    print(f"number {i} : occurrence {list.count(i)}")
# Out:
# number 2 : occurrence 2
# number 3 : occurrence 1
# number 4 : occurrence 1
# number 5 : occurrence 1
# number 6 : occurrence 1
# number 11 : occurrence 4
# number 55 : occurrence 2

# %% [markdown]
# ### 13) WAP to find second largest number in a list.

# %%
list = [1,2,4,6,7]

# for i in list:
#     if(max(list) != i):
#         list2.append(i)

# print(max(list2))

list.sort()  # Must Be Remember Its Not Return List

print(list[-2])
# Out:
# 6

# %% [markdown]
# ### 14) WAP to extract elements with frequency greater than K.

# %%
list = [11,2,2,3,4,5,55,6,11,11,55,11]

k = int(input("Enter K : "))

for i in set(list): 
    if(list.count(i) > k):
        print(f"number {i} : occurrence {list.count(i)}")
# Out:
# Enter K :  1
# number 2 : occurrence 2
# number 11 : occurrence 4
# number 55 : occurrence 2

# %% [markdown]
# ### 15) WAP to create a list of squared numbers from 0 to 9 with and without using List Comprehension.

# %%
list = []

for i in range(0,10):
    list.append(i*i)

# or comprehencen

list = [i*i for i in range(0,10)]

print(list)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### 16) WAP to create a new list (fruit whose name starts with 'b') from the list of fruits given by user.

# %%
n = int(input("Enter Length : "))

list = []

for i in range(n):     
    list.append(input(f"Enter {i+1} Element :"))

fruit = []

for i in list:
    if(i[0] == "b"):
        fruit.append(i)

print(fruit)
# Out:
# Enter Length :  3
# Enter 1 Element : apple
# Enter 2 Element : banana
# Enter 3 Element : mengo
# ['banana']

# %% [markdown]
# ### 17) WAP to create a list of common elements from given two lists.

# %%
list = [1,2,3,4]
list2 = [1,3,6,8,7]
list3 = []

for i in list:
    if(list2.count(i) != 0):
        list3.append(i)

print(list3)
# Out:
# [1, 3]
