# %% [markdown]
# ## Practical 1: Student Marks Analyzer
#
# ### Problem Definition
# Store student data as a list of tuples. Remove duplicate marks, calculate average marks and store result in a dictionary.
#
# ### Sample Input
# ```python
# students = [
#     (1, "Amit", [78, 85, 90, 85]),
#     (2, "Neha", [88, 92, 79, 88]),
#     (3, "Ravi", [70, 75, 80, 75])
# ]
# ```
#
# ### Sample Output
# ```
# {1: ('Amit', 84.33), 2: ('Neha', 86.33), 3: ('Ravi', 75.0)}
#
# ```

# %%
students = [
    (1, "Amit", [78, 85, 90, 85]),
    (2, "Neha", [88, 92, 79, 88]),
    (3, "Ravi", [70, 75, 80, 75])
]


stu = {i:(j, round(sum(set(k))/len(set(k)),2) ) for i,j,k in students}

print(stu)
# Out:
# {1: ('Amit', 84.33), 2: ('Neha', 86.33), 3: ('Ravi', 75.0)}

# %% [markdown]
# ## Practical 2: Inventory Management
#
# ### Problem Definition
# Remove out-of-stock items and calculate total inventory value.
#
# ### Sample Input
# ```python
# inventory = {
#     'pen': (10, 50),
#     'book': (100, 0),
#     'pencil': (5, 100)
# }
# ```
#
# ### Sample Output
# ```
# {'pen': (10, 50), 'pencil': (5, 100)}
# Total Value: 1000
# ```

# %%
inventory = {
    'pen': (10, 50),
    'book': (100, 0),
    'pencil': (5, 100)
}

di = {}

total = 0

for i,j in inventory.items():
    if(j[1] != 0):
        di.update({i:j})
        total += j[0]*j[1] 

print(di)
print("Total :",total)
# Out:
# {'pen': (10, 50), 'pencil': (5, 100)}
# Total : 1000

# %% [markdown]
# ## Practical 3: Email Domain Extractor
#
# ### Problem Definition
# Extract email domains and count occurrences.
#
# ### Sample Input
# ```python
# emails = ['a@gmail.com', 'b@yahoo.com', 'c@gmail.com']
# ```
#
# ### Sample Output
# ```
# {'gmail.com': 2, 'yahoo.com': 1}
# ```

# %%
emails = ['a@gmail.com', 'b@yahoo.com', 'c@gmail.com']

dict = {}

for i in emails:
    str = ""
    for j in range(i.index("@")+1,len(i)):
        str += i[j]
    
    dict.update({str:dict.get(str,0)+1})

    # or

    # dom=i.split('@')[1]
    # dict[dom]=dict.get(dom, 0)+1

print(dict)
# Out:
# {'gmail.com': 2, 'yahoo.com': 1}

# %% [markdown]
# ## Practical 4: Shopping Cart Billing
#
# ### Problem Definition
# Calculate item-wise cost and total bill.
#
# ### Sample Input
# ```
# cart = [('apple',2), ('banana',3)]
# prices = {'apple':50, 'banana':10}
# ```
#
# ### Sample Output
# ```
# {'apple': 100, 'banana': 30}
# Total Bill: 130
# ```

# %%
cart = [('apple',2), ('banana',3)]
prices = {'apple':50, 'banana':10}

di = {}

total = 0

for k,v in cart:
    di.update({k:v})

for k,v in prices.items():
    di[k] *= v
    total += di[k]

print(di)
print("Total :",total)
# Out:
# {'apple': 100, 'banana': 30}
# Total : 130

# %% [markdown]
# ## Practical 5: Character Position Index
#
# ### Problem Definition
# Store positions of each character in a string.
#
# ### Sample Input
# ```python
# s = "banana"
# ```
#
# ### Sample Output
# ```
# {'b': [0], 'a': [1, 3, 5], 'n': [2, 4]}
# ```

# %%
s = "banana"

di = {}

def occurance(ch):
    li = []
    for i in range(len(s)):
        if s[i] == ch:
            li.append(i)
    return li

for ch in s:
    di.update({ch:occurance(ch)})

print(di)
# Out:
# {'b': [0], 'a': [1, 3, 5], 'n': [2, 4]}

# %% [markdown]
# ## Practical 6: Survey Data Aggregation
#
# ### Problem Definition
# Count responses city-wise and choice-wise.
#
# ### Sample Input
# ```python
# responses = [
#     ('Amit','Rajkot','Yes'),
#     ('Neha','Rajkot','No'),
#     ('Ravi','Ahmedabad','Yes')
# ]
# ```
#
# ### Sample Output
# ```
# {'Rajkot': {'Yes': 1, 'No': 1}, 'Ahmedabad': {'Yes': 1}}
# ```

# %%
responses = [
    ('Amit','Rajkot','Yes'),
    ('Neha','Rajkot','No'),
    ('Ravi','Ahmedabad','Yes')
]

di = {}

for name,city,ans in responses:
    if city not in di:
        di[city] = {}
        
    di[city][ans] = di[city].get(ans, 0) + 1

print(di)
# Out:
# {'Rajkot': {'Yes': 1, 'No': 1}, 'Ahmedabad': {'Yes': 1}}
